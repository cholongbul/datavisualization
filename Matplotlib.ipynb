# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot([1,2,3,4,5,6,7], [9,7,8,2,4,6,7])

# %%
fig, ax = plt.subplots(2,2)

# %%
#https://matplotlib.org/stable/tutorials/introductory/usage.html
