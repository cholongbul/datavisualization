# %% [markdown]
# <h1>Seaborn</h1>
# <a href="https://seaborn.pydata.org/examples/index.html">예제</a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = sns.load_dataset('tips')

sns.catplot(x='day', y='total_bill', data=df)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
sns.set_theme('talk')
g = sns.relplot(data=penguins, x='flipper_length_mm', y = 'bill_length_mm', col='island', hue='sex', style='species') #kind='line'
#g.set_xticklabels(rotation=90)

# %%
sns.set_theme(style='whitegrid')
random_state = np.random.RandomState(365)
values = random_state.randn(365, 4).cumsum(axis=0)
dates = pd.date_range('2 2 2020', periods=365, freq='D')
df = pd.DataFrame(values, dates, columns=['A','B','C','D'])
df = df.rolling(7).mean()
df.fillna(1)
# Out:
#                     A          B          C          D
# 2020-02-02   1.000000   1.000000   1.000000   1.000000
# 2020-02-03   1.000000   1.000000   1.000000   1.000000
# 2020-02-04   1.000000   1.000000   1.000000   1.000000
# 2020-02-05   1.000000   1.000000   1.000000   1.000000
# 2020-02-06   1.000000   1.000000   1.000000   1.000000
# ...               ...        ...        ...        ...
# 2021-01-27 -18.482826  10.330142 -12.108625  14.878444
# 2021-01-28 -18.693797  10.391382 -12.020502  15.376387
# 2021-01-29 -18.752957  10.062616 -11.685921  15.996722
# 2021-01-30 -18.918042   9.957435 -11.244617  16.669990
# 2021-01-31 -19.239433  10.189316 -10.733219  17.307552
#
# [365 rows x 4 columns]

# %%
sns.set(rc={'figure.figsize':(10.37,15.8)})
sns.lineplot(data=df, palette='tab10', linewidth=3.5)
# Out:
# <AxesSubplot:>

# %%
import pandas_datareader.data as web
import datetime

# %%
stock = ['GooG', 'MSFT','APPL', 'TSLA']
df = web.DataReader(stock, data_source='yahoo')
df.head(100)
# Out:
# /home/jmoh/anaconda3/lib/python3.9/site-packages/pandas_datareader/base.py:272: SymbolWarning: Failed to read symbol: 'APPL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# Attributes   Adj Close                                  Close             \
# Symbols           GooG       MSFT       TSLA APPL        GooG       MSFT
# Date
# 2017-04-11  823.349976  61.124592  61.742001  NaN  823.349976  65.480003
# 2017-04-12  824.320007  60.891216  59.368000  NaN  824.320007  65.230003
# 2017-04-13  823.559998  60.629826  60.799999  NaN  823.559998  64.949997
# 2017-04-17  837.169983  61.124592  60.287998  NaN  837.169983  65.480003
# 2017-04-18  836.820007  61.040585  60.049999  NaN  836.820007  65.389999
# ...                ...        ...        ...  ...         ...        ...
# 2017-08-25  915.890015  68.730240  69.610001  NaN  915.890015  72.820000
# 2017-08-28  913.809998  68.739700  69.132004  NaN  913.809998  72.830002
# 2017-08-29  921.289978  68.947334  69.472000  NaN  921.289978  73.050003
# 2017-08-30  929.570007  69.853409  70.636002  NaN  929.570007  74.010002
# 2017-08-31  939.330017  70.570740  71.180000  NaN  939.330017  74.769997
#
# Attributes                        High             ...        Low       \
# Symbols          TSLA APPL        GooG       MSFT  ...       TSLA APPL
# Date                                               ...
# 2017-04-11  61.742001  NaN  827.427002  65.610001  ...  61.099998  NaN
# 2017-04-12  59.368000  NaN  826.659973  65.510002  ...  59.264000  NaN
# 2017-04-13  60.799999  NaN  826.380005  65.860001  ...  59.060001  NaN
# 2017-04-17  60.287998  NaN  837.750000  65.489998  ...  59.736000  NaN
# 2017-04-18  60.049999  NaN  838.929993  65.709999  ...  59.580002  NaN
# ...               ...  ...         ...        ...  ...        ...  ...
# 2017-08-25  69.610001  NaN  925.554993  73.349998  ...  69.459999  NaN
# 2017-08-28  69.132004  NaN  919.244995  73.089996  ...  67.944000  NaN
# 2017-08-29  69.472000  NaN  923.330017  73.160004  ...  67.750000  NaN
# 2017-08-30  70.636002  NaN  930.818970  74.209999  ...  69.400002  NaN
# 2017-08-31  71.180000  NaN  941.979980  74.959999  ...  70.564003  NaN
#
# Attributes        Open                                Volume              \
# Symbols           GooG       MSFT       TSLA APPL       GooG        MSFT
# Date
# 2017-04-11  824.710022  65.599998  62.675999  NaN  1079700.0  18791500.0
# 2017-04-12  821.929993  65.419998  61.268002  NaN   900500.0  17108500.0
# 2017-04-13  822.140015  65.290001  59.340000  NaN  1122400.0  17896500.0
# 2017-04-17  825.010010  65.040001  60.540001  NaN   895000.0  16689300.0
# 2017-04-18  834.219971  65.330002  59.939999  NaN   836700.0  15155600.0
# ...                ...        ...        ...  ...        ...         ...
# 2017-08-25  923.489990  72.860001  70.848000  NaN  1053400.0  12794300.0
# 2017-08-28  916.000000  73.059998  69.456001  NaN  1086500.0  14569700.0
# 2017-08-29  905.099976  72.250000  67.896004  NaN  1185600.0  11478400.0
# 2017-08-30  920.049988  73.010002  69.933998  NaN  1301200.0  16897800.0
# 2017-08-31  931.760010  74.029999  70.709999  NaN  1582600.0  27652800.0
#
# Attributes
# Symbols           TSLA APPL
# Date
# 2017-04-11  28623000.0  NaN
# 2017-04-12  30253500.0  NaN
# 2017-04-13  46423000.0  NaN
# 2017-04-17  20693500.0  NaN
# 2017-04-18  15178500.0  NaN
# ...                ...  ...
# 2017-08-25  17420000.0  NaN
# 2017-08-28  18820000.0  NaN
# 2017-08-29  20368500.0  NaN
# 2017-08-30  17064500.0  NaN
# 2017-08-31  20364000.0  NaN
#
# [100 rows x 24 columns]

# %%
sns.set_theme(style="whitegrid")
fig, ax = plt.subplots()
fig.set_size_inches(12,9)

sns.lineplot(data=df['Close'], palette='bright',linewidth=3.5)
# Out:
# <AxesSubplot:xlabel='Date'>
